# %% [markdown]
# # Data Analysis and Data Visualization Day

# %%
# Import needed libraries 
import pandas as pd
import numpy as np

# %%
# Read the csv file "ames_clean.csv"
df = pd.read_csv('ames_clean.csv')
df
# Out:
#      MSZoning  LotFrontage  LotArea Street     Alley LotShape LandContour  \
# 0          RL        141.0    31770   Pave  No Alley      IR1         Lvl
# 1       Other         80.0    11622   Pave  No Alley      Reg         Lvl
# 2          RL         81.0    14267   Pave  No Alley      IR1         Lvl
# 3          RL         93.0    11160   Pave  No Alley      Reg         Lvl
# 4          RL         74.0    13830   Pave  No Alley      IR1         Lvl
# ...       ...          ...      ...    ...       ...      ...         ...
# 2833       RL         37.0     7937   Pave  No Alley      IR1         Lvl
# 2834       RL         74.0     8885   Pave  No Alley      IR1         Low
# 2835       RL         62.0    10441   Pave  No Alley      Reg         Lvl
# 2836       RL         77.0    10010   Pave  No Alley      Reg         Lvl
# 2837       RL         74.0     9627   Pave  No Alley      Reg         Lvl
#
#      LotConfig LandSlope Neighborhood  ... 3SsnPorch ScreenPorch PoolArea  \
# ...

# %%
# use the describe function to describe the dataset
df.describe()
# Out:
#        LotFrontage        LotArea    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  2838.000000    2838.000000  2838.000000   2838.000000  2838.000000
# mean     69.227449   10070.431290  1971.235729   1984.228682    97.678295
# std      21.603608    7852.951638    29.959692     20.700583   170.217979
# min      21.000000    1300.000000  1872.000000   1950.000000     0.000000
# 25%      60.000000    7416.250000  1954.000000   1966.000000     0.000000
# 50%      70.000000    9378.500000  1973.000000   1993.000000     0.000000
# 75%      80.000000   11448.500000  2000.000000   2003.750000   161.000000
# max     313.000000  215245.000000  2010.000000   2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  ...  \
# count  2838.000000  2838.000000  2838.000000  2838.000000  2838.000000  ...
# mean    438.120860    50.381254   557.387597  1045.889711  1153.770965  ...
# ...

# %% [markdown]
# # Now take around 10 minutes and then find out what each value means
#
# ## What does count/mean/sdt/min/25%/50%/75%/max mean?

# %%
#descriptive statistics summary
df['SalePrice'].describe()
# Out:
# count      2838.000000
# mean     178085.577872
# std       70175.787024
# min       62383.000000
# 25%      129900.000000
# 50%      160000.000000
# 75%      212000.000000
# max      455000.000000
# Name: SalePrice, dtype: float64

# %%
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape',
#        'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
# ...

# %%
print(df.shape)
# Out:
# (2838, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2838 entries, 0 to 2837
# Data columns (total 74 columns):
# MSZoning         2838 non-null object
# LotFrontage      2838 non-null float64
# LotArea          2838 non-null int64
# Street           2838 non-null object
# Alley            2838 non-null object
# LotShape         2838 non-null object
# LandContour      2838 non-null object
# LotConfig        2838 non-null object
# LandSlope        2838 non-null object
# Neighborhood     2838 non-null object
# Condition1       2838 non-null object
# Condition2       2838 non-null object
# BldgType         2838 non-null object
# HouseStyle       2838 non-null object
# YearBuilt        2838 non-null int64
# YearRemodAdd     2838 non-null int64
# RoofStyle        2838 non-null object
# RoofMatl         2838 non-null object
# Exterior1st      2838 non-null object
# Exterior2nd      2838 non-null object
# MasVnrType       2838 non-null object
# MasVnrArea       2838 non-null int64
# ...

# %%
#install and Import libraries matplotib and seaborn
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Search what is histogram

# %%
#histogram
df['SalePrice'].hist(bins=50)
# try to change the bin numbers

# %%
#skewness and kurtosis? WHat are they?
print("Skewness: %f" % df['SalePrice'].skew())
print("Kurtosis: %f" % df['SalePrice'].kurt())
# Out:
# Skewness: 1.211370
# Kurtosis: 1.473712

# %% [markdown]
# ### We scatter plot to look at correlation

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,500000));

# %%
#scatter plot number of area/saleprice 
data = pd.concat([df['SalePrice'],df['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0,500000))

# %%
df.boxplot(column='SalePrice')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr())
plt.show()

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(corrmat, vmax=.8, square=True, annot=True)

# %%
# select correlation of SalePrice
df_sp = pd.DataFrame(df.corr()['SalePrice'])
# select data where correlation coefficient more than 0.5
df_sp = df_sp[df_sp['SalePrice'] >= 0.5]
df_sp
# Out:
#               SalePrice
# YearBuilt      0.574154
# YearRemodAdd   0.542904
# TotalBsmtSF    0.600388
# 1stFlrSF       0.589686
# GrLivArea      0.677643
# FullBath       0.546264
# GarageCars     0.651297
# GarageArea     0.634822
# SalePrice      1.000000

# %% [markdown]
# ## We found more influential columns for SalePrice and created new DataFrame

# %%
# Select most influential columns of data  
data_for_model = df[['YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','GarageCars','GarageArea','SalePrice']]
data_for_model
# Out:
#       YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# 0          1960          1960         1080      1656       1656         1
# 1          1961          1961          882       896        896         1
# 2          1958          1958         1329      1329       1329         1
# 3          1968          1968         2110      2110       2110         2
# 4          1997          1998          928       928       1629         2
# ...         ...           ...          ...       ...        ...       ...
# 2833       1984          1984         1003      1003       1003         1
# 2834       1983          1983          864       902        902         1
# 2835       1992          1992          912       970        970         1
# 2836       1974          1975         1389      1389       1389         1
# 2837       1993          1994          996       996       2000         2
#
#       GarageCars  GarageArea  SalePrice
# ...

# %% [markdown]
# ## There is a description of columns that we choosed for model:
# #### 1. YearBuilt: Original construction date
# #### 2. YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
# #### 3. TotalBsmtSF: Total square feet of basement area
# #### 4. 1stFlrSF: First Floor square feet
# #### 5. GrLivArea: Above grade (ground) living area square feet
# #### 6. FullBath: Full bathrooms above grade
# #### 5. GarageCars: Size of garage in car capacity
# #### 6. GarageArea: Size of garage in square feet
